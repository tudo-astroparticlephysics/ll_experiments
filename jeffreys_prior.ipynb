# %%
import sympy
from sympy import Symbol, factorial, exp, init_printing, diff, solve, log, simplify, limit, expand, sqrt, summation, oo, Matrix, det
init_printing()
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Simple poisson distribution
#
# Lets start by calculating it for a poisson distribution. See also https://en.wikipedia.org/wiki/Jeffreys_prior

# %%
lam = Symbol('lambda', positive=True)
n = Symbol('n', positive=True, integer=True)

f = exp(-lam)*lam**n / factorial(n)
f, log(f).simplify()
# Out:
# ⎛ n  -λ                         ⎞
# ⎜λ ⋅ℯ                           ⎟
# ⎜──────, -λ + n⋅log(λ) - log(n!)⎟
# ⎝  n!                           ⎠

# %%
d_log_f = diff(log(f), lam)
expectation_value = summation(f*d_log_f**2, (n, 0, oo))
prior = sqrt(expectation_value.simplify())
prior
# Out:
# 1
# ──
# √λ

# %%
rate = np.linspace(0.01, 6, 100)
p = np.exp(-rate)*rate
# plt.plot(rate, 1/np.sqrt(rate))
plt.plot(rate, p)
plt.plot(rate, p/np.sqrt(rate))

# %% [markdown]
# Same thing just use the variables we actually have in the on region

# %%
mu_s = Symbol('mu_s', positive=True)
mu_b = Symbol('mu_b', positive=True)
alpha = Symbol('alpha', positive=True, constant=True)
n_on = Symbol('n_on', positive=True, integer=True)

lam = mu_s + alpha*mu_b
f = exp(-lam)*lam**n_on / factorial(n_on)
f, log(f).simplify()
# Out:
# ⎛            nₒₙ  -α⋅μ_b - μₛ                                               ⎞
# ⎜(α⋅μ_b + μₛ)   ⋅ℯ                                                          ⎟
# ⎜────────────────────────────, -α⋅μ_b - μₛ + nₒₙ⋅log(α⋅μ_b + μₛ) - log(nₒₙ!)⎟
# ⎝            nₒₙ!                                                           ⎠

# %% [markdown]
# ## Full likelihood with background expression
#
# It is a product of poissons.

# %%
mu_s = Symbol('mu_s', positive=True)
mu_b = Symbol('mu_b', positive=True)
alpha = Symbol('alpha', positive=True)
n_on = Symbol('n_on', positive=True, integer=True)
n_off = Symbol('n_off', positive=True, integer=True)

lam1 = (alpha * mu_b + mu_s)
lam1
lam2 = mu_b
lam2
f1 = exp(-lam1)*lam1**n_on / factorial(n_on)
f2 = exp(-lam2)*lam2**n_off / factorial(n_off)

likelihood = f1*f2
f1, f2, likelihood
# Out:
# ⎛            nₒₙ  -α⋅μ_b - μₛ     n_off  -μ_b     n_off             nₒₙ  -μ_b
# ⎜(α⋅μ_b + μₛ)   ⋅ℯ             μ_b     ⋅ℯ      μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅
# ⎜────────────────────────────, ──────────────, ───────────────────────────────
# ⎝            nₒₙ!                  n_off!                      n_off!⋅nₒₙ!
#
#  -α⋅μ_b - μₛ⎞
# ℯ           ⎟
# ────────────⎟
#             ⎠

# %% [markdown]
# and the logarithmic likelihood

# %%
log(likelihood).expand().simplify()
# Out:
# -α⋅μ_b - μ_b - μₛ + n_off⋅log(μ_b) + nₒₙ⋅log(α⋅μ_b + μₛ) - log(n_off!) - log(n
# ₒₙ!)

# %% [markdown]
# #### Limits
# To implement the function as code we have to check the limits for the parameters going to 0. Startign with n_off below

# %%
limit_n_off = limit(likelihood, n_off, 0, dir='+')
log(limit_n_off).expand().simplify()
# Out:
# -α⋅μ_b - μ_b - μₛ + nₒₙ⋅log(α⋅μ_b + μₛ) - log(nₒₙ!)

# %% [markdown]
# Lets do the same for n_on

# %%
limit_n_on = limit(likelihood, n_on, 0, dir='+')
log(limit_n_on).expand().simplify()
# Out:
# -α⋅μ_b - μ_b - μₛ + n_off⋅log(μ_b) - log(n_off!)

# %% [markdown]
# And for both at once

# %%
limit_n_both = limit(limit(likelihood, n_on, 0, dir='+'), n_off, 0, dir='+')
log(limit_n_both).expand().simplify()
# Out:
# -α⋅μ_b - μ_b - μₛ

# %%
limit_mu_b = limit(likelihood, mu_b, 0, dir='+')
limit_mu_b
# Out:
# 0

# %% [markdown]
# #### Fisher information ad Jeffreys prior

# %%
g = log(likelihood)
m = Matrix([[diff(g, mu_s)**2,  diff(g, mu_s) * diff(g, mu_b)], [diff(g, mu_s) * diff(g, mu_b),  diff(g, mu_b)**2]])
# m = Matrix([[ll*diff(g, mu_s)**2,  ll*diff(g, mu_s) * diff(g, mu_b)], [ll*diff(g, mu_s) * diff(g, mu_b),  ll*diff(g, mu_b)**2]])
m
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                               ⎛   n_off                 nₒₙ  -μ_b  -α⋅μ_b -
# ⎢   -2⋅n_off             -2⋅nₒₙ ⎜μ_b     ⋅nₒₙ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ
# ⎢μ_b        ⋅(α⋅μ_b + μₛ)      ⋅⎜─────────────────────────────────────────────
# ⎣                               ⎝            (α⋅μ_b + μₛ)⋅n_off!⋅nₒₙ!
#
#
#                                                     ⎛   n_off
#                         -2⋅n_off             -2⋅nₒₙ ⎜μ_b     ⋅nₒₙ⋅(α⋅μ_b + μₛ)
#                      μ_b        ⋅(α⋅μ_b + μₛ)      ⋅⎜─────────────────────────
#                                                     ⎝            (α⋅μ_b + μₛ)⋅
#
#
# μₛ      n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ⎞ ⎛     n_off
#      μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ           ⎟ ⎜α⋅μ_b     ⋅nₒₙ⋅(α⋅μ_b + μₛ)
# ── - ───────────────────────────────────────────⎟⋅⎜───────────────────────────
#                      n_off!⋅nₒₙ!                ⎠ ⎝             (α⋅μ_b + μₛ)⋅n
#
#                                                                      2
# nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ⎞
#    ⋅ℯ    ⋅ℯ              μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ           ⎟   2⋅μ_b
# ────────────────────── - ───────────────────────────────────────────⎟ ⋅ℯ     ⋅
# n_off!⋅nₒₙ!                              n_off!⋅nₒₙ!                ⎠
#
#
# nₒₙ  -μ_b  -α⋅μ_b - μₛ        n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_
#    ⋅ℯ    ⋅ℯ              α⋅μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b
# ────────────────────── - ───────────────────────────────────────────── - ─────
# _off!⋅nₒₙ!                                n_off!⋅nₒₙ!
#
#
#
#  2⋅α⋅μ_b + 2⋅μₛ       2     2
# ℯ              ⋅n_off! ⋅nₒₙ!
#
#
#
# off             nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_off                   nₒₙ  -μ_b
#    ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b     ⋅n_off⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅
# ────────────────────────────────────── + ─────────────────────────────────────
#            n_off!⋅nₒₙ!                                    μ_b⋅n_off!⋅nₒₙ!
#
#
#
#                                                        -2⋅n_off             -2
#                                                     μ_b        ⋅(α⋅μ_b + μₛ)
#
#
#
#  -α⋅μ_b - μₛ⎞
# ℯ           ⎟  2⋅μ_b  2⋅α⋅μ_b + 2⋅μₛ       2     2
# ────────────⎟⋅ℯ     ⋅ℯ              ⋅n_off! ⋅nₒₙ!
#             ⎠
#
#
#      ⎛   n_off                 nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_off             n
# ⋅nₒₙ ⎜μ_b     ⋅nₒₙ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b     ⋅(α⋅μ_b + μₛ)
#     ⋅⎜─────────────────────────────────────────────── - ──────────────────────
#      ⎝            (α⋅μ_b + μₛ)⋅n_off!⋅nₒₙ!                              n_off!
#
#
#                                                     ⎛     n_off
#                         -2⋅n_off             -2⋅nₒₙ ⎜α⋅μ_b     ⋅nₒₙ⋅(α⋅μ_b + μ
#                      μ_b        ⋅(α⋅μ_b + μₛ)      ⋅⎜─────────────────────────
#                                                     ⎝             (α⋅μ_b + μₛ)
#
#
# ₒₙ  -μ_b  -α⋅μ_b - μₛ⎞ ⎛     n_off                 nₒₙ  -μ_b  -α⋅μ_b - μₛ
#   ⋅ℯ    ⋅ℯ           ⎟ ⎜α⋅μ_b     ⋅nₒₙ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              α⋅
# ─────────────────────⎟⋅⎜───────────────────────────────────────────────── - ──
# ⋅nₒₙ!                ⎠ ⎝             (α⋅μ_b + μₛ)⋅n_off!⋅nₒₙ!
#
#
#   nₒₙ  -μ_b  -α⋅μ_b - μₛ        n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ
# ₛ)   ⋅ℯ    ⋅ℯ              α⋅μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b
# ──────────────────────── - ───────────────────────────────────────────── - ───
# ⋅n_off!⋅nₒₙ!                                n_off!⋅nₒₙ!
#
#
#    n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_off             nₒₙ  -μ_b
# μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ
# ─────────────────────────────────────────── - ────────────────────────────────
#                n_off!⋅nₒₙ!                                    n_off!⋅nₒₙ!
#
#
# n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ      n_off                   nₒₙ  -μ_
#      ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ              μ_b     ⋅n_off⋅(α⋅μ_b + μₛ)   ⋅ℯ
# ──────────────────────────────────────── + ───────────────────────────────────
#              n_off!⋅nₒₙ!                                    μ_b⋅n_off!⋅nₒₙ!
#
#
# -α⋅μ_b - μₛ      n_off                   nₒₙ  -μ_b  -α⋅μ_b - μₛ⎞
#               μ_b     ⋅n_off⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ           ⎟  2⋅μ_b  2⋅α⋅μ
# ─────────── + ─────────────────────────────────────────────────⎟⋅ℯ     ⋅ℯ
#                                μ_b⋅n_off!⋅nₒₙ!                 ⎠
#
#                2
# b  -α⋅μ_b - μₛ⎞
#  ⋅ℯ           ⎟   2⋅μ_b  2⋅α⋅μ_b + 2⋅μₛ       2     2
# ──────────────⎟ ⋅ℯ     ⋅ℯ              ⋅n_off! ⋅nₒₙ!
#               ⎠
#
#                        ⎤
#                        ⎥
# _b + 2⋅μₛ       2     2⎥
#          ⋅n_off! ⋅nₒₙ! ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎦

# %%
a = summation(likelihood*m, (n_on, 0, oo))
b = summation(a, (n_off, 0, oo))
b
# Out:
# ⎡                                                    2
# ⎢  α⋅μ_b          μₛ               1                α ⋅μ_b        α⋅μₛ
# ⎢────────── + ────────── - 1 + ──────────         ────────── + ────────── - α
# ⎢α⋅μ_b + μₛ   α⋅μ_b + μₛ       α⋅μ_b + μₛ         α⋅μ_b + μₛ   α⋅μ_b + μₛ
# ⎢
# ⎢   2                                         3            2
# ⎢  α ⋅μ_b        α⋅μₛ              α         α ⋅μ_b       α ⋅μₛ       2
# ⎢────────── + ────────── - α + ──────────  ────────── + ────────── - α  + ────
# ⎣α⋅μ_b + μₛ   α⋅μ_b + μₛ       α⋅μ_b + μₛ  α⋅μ_b + μₛ   α⋅μ_b + μₛ        α⋅μ_
#
#                     ⎤
#       α             ⎥
# + ──────────        ⎥
#   α⋅μ_b + μₛ        ⎥
#                     ⎥
#  2                  ⎥
# α            μ_b + 1⎥
# ────── - 1 + ───────⎥
# b + μₛ         μ_b  ⎦

# %%
sqrt(b.det()).simplify()
# Out:
#           1
# ──────────────────────
#   _____   ____________
# ╲╱ μ_b ⋅╲╱ α⋅μ_b + μₛ

# %% [markdown]
# ## Weird stuff below.
# Easy as pie. Now lets try for wstat. Lets do the regular likelihood first.

# %%
mu_s, mu_b, alpha, n_on, n_off = Symbol('mu_s', positive=True), Symbol('mu_b', positive=True), Symbol('alpha', positive=True), Symbol('n_on', positive=True, integer=True), Symbol('n_off', positive=True, integer=True)

# %%
likelihood = ((mu_s + alpha * mu_b)**n_on)/factorial(n_on) * exp(-(mu_s + alpha*mu_b)) * ((mu_b)**n_off)/factorial(n_off) * exp(-mu_b)
log_likelihood = log(likelihood).expand().simplify()
f = likelihood * diff(log_likelihood, mu_s) * diff(log_likelihood, mu_b)
f
# Out:
#    n_off             nₒₙ ⎛   nₒₙ        ⎞ ⎛  α⋅nₒₙ              n_off⎞  -μ_b
# μ_b     ⋅(α⋅μ_b + μₛ)   ⋅⎜────────── - 1⎟⋅⎜────────── - α - 1 + ─────⎟⋅ℯ    ⋅ℯ
#                          ⎝α⋅μ_b + μₛ    ⎠ ⎝α⋅μ_b + μₛ            μ_b ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                        n_off!⋅nₒₙ!
#
# -α⋅μ_b - μₛ
#
#
# ───────────

# %% [markdown]
# Lets see what the limit of the likelihood looks like for n_on and n_off to 0

# %%
likelihood
# Out:
#    n_off             nₒₙ  -μ_b  -α⋅μ_b - μₛ
# μ_b     ⋅(α⋅μ_b + μₛ)   ⋅ℯ    ⋅ℯ
# ───────────────────────────────────────────
#                 n_off!⋅nₒₙ!

# %%
log(limit(likelihood, n_on, 0, dir='+')).expand().simplify()
# Out:
# -α⋅μ_b - μ_b - μₛ + n_off⋅log(μ_b) - log(n_off!)

# %%
a = summation(f, (n_on, 0, oo))
b = summation(a, (n_off, 0, oo))
sqrt(b)
# Out:
#      __________________________________________
#     ╱    2
#    ╱    α ⋅μ_b        α⋅μₛ              α
#   ╱   ────────── + ────────── - α + ──────────
# ╲╱    α⋅μ_b + μₛ   α⋅μ_b + μₛ       α⋅μ_b + μₛ

# %% [markdown]
# So here we go. The results look reasonable for wstat.
# If it works for the complete wstat likelihood lets try for the profile.

# %%
mu_b_of_s, _ = solve(diff(log(likelihood), mu_b), mu_b)
mu_b_of_s
# Out:
#                                   ____________________________________________
#                                  ╱  2   2      2               2           2
# -α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n
# ──────────────────────────────────────────────────────────────────────────────
#                                                                         2⋅α⋅(α
#
# _____________________________________________________________________________
#     2      2              2    2         2                                 2
# _off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ─────────────────────────────────────────────────────────────────────────────
#  + 1)

# %%
limit(mu_b_of_s, n_on, 0)
# Out:
#                        ⎛                          ____________________________
#                        ⎜                         ╱  2   2      2             2
# -log(2⋅α⋅(α + 1)) + log⎝-α⋅μₛ + α⋅n_off - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off + α
#
# _______________________________________⎞
#       2         2                    2 ⎟
# ⋅n_off  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off + μₛ  ⎠

# %%
profile_likelihood = ((mu_s + alpha * mu_b_of_s)**n_on)/factorial(n_on) * exp(-(mu_s + alpha*mu_b_of_s)) * ((mu_b_of_s)**n_off)/factorial(n_off) * exp(-mu_b_of_s)
profile_likelihood
# Out:
#
#
# ⎛                                  ___________________________________________
# ⎜                                 ╱  2   2      2               2           2
# ⎜-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅
# ⎜─────────────────────────────────────────────────────────────────────────────
# ⎝                                                                        2⋅α⋅(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#      2      2              2    2         2                                 2
# n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ──────────────────────────────────────────────────────────────────────────────
# α + 1)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  n_off
# ⎞      ⎛                                       _______________________________
# ⎟      ⎜                                      ╱  2   2      2               2
# ⎟      ⎜     -α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅
# ⎟     ⋅⎜μₛ + ─────────────────────────────────────────────────────────────────
# ⎠      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#           2      2      2              2    2         2
# μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μ
# ──────────────────────────────────────────────────────────────────────────────
#         2⋅(α + 1)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    ⎛                                  ________________________
#              nₒₙ   ⎜                                 ╱  2   2      2
# ____________⎞     -⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off
#           2 ⎟     ────────────────────────────────────────────────────────────
# ₛ⋅nₒₙ + μₛ  ⎟
# ────────────⎟   ⋅ℯ
#             ⎠
# ──────────────────────────────────────────────────────────────────────────────
#         n_off!⋅nₒₙ!
#
# ______________________________________________________________________________
#      2           2      2      2              2    2         2
# - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off
# ──────────────────────────────────────────────────────────────────────────────
#               2⋅α⋅(α + 1)
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ___________________⎞                                           _______________
#                  2 ⎟                                          ╱  2   2      2
# - 2⋅α⋅μₛ⋅nₒₙ + μₛ  ⎠         -α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅
# ─────────────────────  -μₛ - ─────────────────────────────────────────────────
#
#                      ⋅ℯ
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#               2           2      2      2              2    2         2
# μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅
# ──────────────────────────────────────────────────────────────────────────────
#                         2⋅(α + 1)
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ____________________________
#                           2
# μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ────────────────────────────
#
#
#
# ────────────────────────────

# %%
log(limit(profile_likelihood, n_on, 0, dir='-')).expand().simplify()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-230-badfe5c3088f> in <module>()
# ----> 1 log(limit(profile_likelihood, n_on, 0, dir='-')).expand().simplify()
#
# /usr/local/lib/python3.6/site-packages/sympy/series/limits.py in limit(e, z, z0, dir)
#      66                     % (llim, rlim))
#      67     else:
# ---> 68         return Limit(e, z, z0, dir).doit(deep=False)
#      69
#      70
#
# /usr/local/lib/python3.6/site-packages/sympy/series/limits.py in doit(self, **hints)
#     211
#     212         try:
# --> 213             r = gruntz(e, z, z0, dir)
#     214             if r is S.NaN:
#     215                 raise PoleError()
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in gruntz(e, z, z0, dir)
#     656         else:
#     657             raise NotImplementedError("dir must be '+' or '-'")
# --> 658         r = limitinf(e0, z)
#     659
#     660     # This is a bit of a heuristic for nice results... we always rewrite
#
# /usr/local/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in limitinf(e, x)
#     426         e = e.subs(x, p)
#     427         x = p
# --> 428     c0, e0 = mrv_leadterm(e, x)
#     429     sig = sign(e0, x)
#     430     if sig == 1:
#
# /usr/local/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv_leadterm(e, x)
#     485         return (e, S.Zero)
#     486     if Omega == SubsSet():
# --> 487         Omega, exps = mrv(e, x)
#     488     if not Omega:
#     489         # e really does not depend on x after simplification
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     259         a, b = d.as_two_terms()
#     260         s1, e1 = mrv(a, x)
# --> 261         s2, e2 = mrv(b, x)
#     262         return mrv_max1(s1, s2, e.func(i, e1, e2), x)
#     263     elif e.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     258             return s, e.func(i, expr)
#     259         a, b = d.as_two_terms()
# --> 260         s1, e1 = mrv(a, x)
#     261         s2, e2 = mrv(b, x)
#     262         return mrv_max1(s1, s2, e.func(i, e1, e2), x)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     266             return SubsSet(), b
#     267         if e.has(x):
# --> 268             return mrv(exp(e * log(b)), x)
#     269         else:
#     270             s, expr = mrv(b, x)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     281         # infinite if there is no zero, otherwise NaN; here, we
#     282         # consider the result infinite if any factor is infinite
# --> 283         li = limitinf(e.args[0], x)
#     284         if any(_.is_infinite for _ in Mul.make_args(li)):
#     285             s1 = SubsSet()
#
# /usr/local/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in limitinf(e, x)
#     426         e = e.subs(x, p)
#     427         x = p
# --> 428     c0, e0 = mrv_leadterm(e, x)
#     429     sig = sign(e0, x)
#     430     if sig == 1:
#
# /usr/local/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in mrv_leadterm(e, x)
#     511     w = Dummy("w", real=True, positive=True, finite=True)
#     512     f, logw = rewrite(exps, Omega, x, w)
# --> 513     series = calculate_series(f, w, logx=logw)
#     514     return series.leadterm(w)
#     515
#
# /usr/local/lib/python3.6/site-packages/sympy/series/gruntz.py in calculate_series(e, x, logx)
#     464     from sympy.polys import cancel
#     465
# --> 466     for t in e.lseries(x, logx=logx):
#     467         t = cancel(t)
#     468
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in yield_lseries(s)
#    2714             def yield_lseries(s):
#    2715                 """Return terms of lseries one at a time."""
# -> 2716                 for si in s:
#    2717                     if not si.is_Add:
#    2718                         yield si
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_lseries(self, x, logx)
#    2789         while series.is_Order:
#    2790             n += 1
# -> 2791             series = self._eval_nseries(x, n=n, logx=logx)
#    2792         e = series.removeO()
#    2793         yield e
#
# /usr/local/lib/python3.6/site-packages/sympy/core/mul.py in _eval_nseries(self, x, n, logx)
#    1650     def _eval_nseries(self, x, n, logx):
#    1651         from sympy import Order, powsimp
# -> 1652         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#    1653         res = powsimp(self.func(*terms).expand(), combine='exp', deep=True)
#    1654         if res.has(Order):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/mul.py in <listcomp>(.0)
#    1650     def _eval_nseries(self, x, n, logx):
#    1651         from sympy import Order, powsimp
# -> 1652         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#    1653         res = powsimp(self.func(*terms).expand(), combine='exp', deep=True)
#    1654         if res.has(Order):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in nseries(self, x, x0, n, dir, logx)
#    2866             return self.series(x, x0, n, dir)
#    2867         else:
# -> 2868             return self._eval_nseries(x, n=n, logx=logx)
#    2869
#    2870     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.6/site-packages/sympy/functions/elementary/exponential.py in _eval_nseries(self, x, n, logx)
#     755
#     756         # TODO new and probably slow
# --> 757         s = self.args[0].nseries(x, n=n, logx=logx)
#     758         while s.is_Order:
#     759             n += 1
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in nseries(self, x, x0, n, dir, logx)
#    2866             return self.series(x, x0, n, dir)
#    2867         else:
# -> 2868             return self._eval_nseries(x, n=n, logx=logx)
#    2869
#    2870     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/add.py in _eval_nseries(self, x, n, logx)
#     384
#     385     def _eval_nseries(self, x, n, logx):
# --> 386         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#     387         return self.func(*terms)
#     388
#
# /usr/local/lib/python3.6/site-packages/sympy/core/add.py in <listcomp>(.0)
#     384
#     385     def _eval_nseries(self, x, n, logx):
# --> 386         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#     387         return self.func(*terms)
#     388
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in nseries(self, x, x0, n, dir, logx)
#    2866             return self.series(x, x0, n, dir)
#    2867         else:
# -> 2868             return self._eval_nseries(x, n=n, logx=logx)
#    2869
#    2870     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/mul.py in _eval_nseries(self, x, n, logx)
#    1650     def _eval_nseries(self, x, n, logx):
#    1651         from sympy import Order, powsimp
# -> 1652         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#    1653         res = powsimp(self.func(*terms).expand(), combine='exp', deep=True)
#    1654         if res.has(Order):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/mul.py in <listcomp>(.0)
#    1650     def _eval_nseries(self, x, n, logx):
#    1651         from sympy import Order, powsimp
# -> 1652         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#    1653         res = powsimp(self.func(*terms).expand(), combine='exp', deep=True)
#    1654         if res.has(Order):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in nseries(self, x, x0, n, dir, logx)
#    2866             return self.series(x, x0, n, dir)
#    2867         else:
# -> 2868             return self._eval_nseries(x, n=n, logx=logx)
#    2869
#    2870     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/add.py in _eval_nseries(self, x, n, logx)
#     384
#     385     def _eval_nseries(self, x, n, logx):
# --> 386         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#     387         return self.func(*terms)
#     388
#
# /usr/local/lib/python3.6/site-packages/sympy/core/add.py in <listcomp>(.0)
#     384
#     385     def _eval_nseries(self, x, n, logx):
# --> 386         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
#     387         return self.func(*terms)
#     388
#
# /usr/local/lib/python3.6/site-packages/sympy/core/expr.py in nseries(self, x, x0, n, dir, logx)
#    2866             return self.series(x, x0, n, dir)
#    2867         else:
# -> 2868             return self._eval_nseries(x, n=n, logx=logx)
#    2869
#    2870     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.6/site-packages/sympy/core/mul.py in _eval_nseries(self, x, n, logx)
#    1651         from sympy import Order, powsimp
#    1652         terms = [t.nseries(x, n=n, logx=logx) for t in self.args]
# -> 1653         res = powsimp(self.func(*terms).expand(), combine='exp', deep=True)
#    1654         if res.has(Order):
#    1655             res += Order(x**n, x)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     119
#     120     if expr.is_Pow:
# --> 121         return recurse(expr*_y, deep=False)/_y
#     122
#     123     if not expr.is_Mul:
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     171                     e.append(m)
#     172                     coeff /= b**m
# --> 173             c_powers[b] = Add(*e)
#     174         if coeff is not S.One:
#     175             if coeff in c_powers:
#
# /usr/local/lib/python3.6/site-packages/sympy/core/basic.py in __hash__(self)
#     119             setattr(self, k, v)
#     120
# --> 121     def __hash__(self):
#     122         # hash cannot be cached using cache_it because infinite recurrence
#     123         # occurs as hash is needed for setting cache dictionary keys
#
# KeyboardInterrupt:

# %%
f = diff(log(profile_likelihood), mu_s).expand().simplify()
# limit(diff(log_profile_likelihood, mu_s), n_on, 0, dir='+')
# Out:
#
#    4   4      2      4   3      3    4   3      2          4   2      4      4
# - α ⋅μₛ ⋅n_off  - 4⋅α ⋅μₛ ⋅n_off  - α ⋅μₛ ⋅n_off ⋅nₒₙ - 6⋅α ⋅μₛ ⋅n_off  - 7⋅α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2      3        4   2      2    2      4         5       4         4
# ⋅μₛ ⋅n_off ⋅nₒₙ - α ⋅μₛ ⋅n_off ⋅nₒₙ  - 4⋅α ⋅μₛ⋅n_off  - 11⋅α ⋅μₛ⋅n_off ⋅nₒₙ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    4         3    2    4         2    3    4             4    4      6      4
# 9⋅α ⋅μₛ⋅n_off ⋅nₒₙ  - α ⋅μₛ⋅n_off ⋅nₒₙ  + α ⋅μₛ⋅n_off⋅nₒₙ  - α ⋅n_off  - 5⋅α ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      5           4      4    2       4      3    3      4      2    4    4
# n_off ⋅nₒₙ - 10⋅α ⋅n_off ⋅nₒₙ  - 10⋅α ⋅n_off ⋅nₒₙ  - 5⋅α ⋅n_off ⋅nₒₙ  - α ⋅n_o
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       5      3   4      2       3   3      3      3   3      2        3   3
# ff⋅nₒₙ  - 4⋅α ⋅μₛ ⋅n_off  - 12⋅α ⋅μₛ ⋅n_off  - 2⋅α ⋅μₛ ⋅n_off ⋅nₒₙ + α ⋅μₛ ⋅n_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#         ______________________________________________________________________
#    2   ╱  2   2      2               2           2      2      2
# off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                      4   4      2      4   3
#                                                     α ⋅μₛ ⋅n_off  + 4⋅α ⋅μₛ ⋅n
#
# ___________________________________________________
# 2    2         2                                 2        3   2      4       3
#  ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 12⋅α ⋅μₛ ⋅n_off  - 11⋅α
# ──────────────────────────────────────────────────────────────────────────────
#
#     3      4   3      2          4   2      4       4   2      3          4
# _off  + 2⋅α ⋅μₛ ⋅n_off ⋅nₒₙ + 6⋅α ⋅μₛ ⋅n_off  + 10⋅α ⋅μₛ ⋅n_off ⋅nₒₙ + 3⋅α ⋅μₛ
#
#                                      _________________________________________
#    2      3          3   2      3   ╱  2   2      2               2
# ⋅μₛ ⋅n_off ⋅nₒₙ + 3⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α
# ──────────────────────────────────────────────────────────────────────────────
#
# 2      2    2    4   2    4      4         5       4         4           4
#  ⋅n_off ⋅nₒₙ  + α ⋅μₛ ⋅nₒₙ  + 4⋅α ⋅μₛ⋅n_off  + 14⋅α ⋅μₛ⋅n_off ⋅nₒₙ + 16⋅α ⋅μₛ⋅
#
# ______________________________________________________________________________
# 2      2      2              2    2         2
#  ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ──────────────────────────────────────────────────────────────────────────────
#
#      3    2      4         2    3      4             4      4       5    4
# n_off ⋅nₒₙ  + 4⋅α ⋅μₛ⋅n_off ⋅nₒₙ  - 4⋅α ⋅μₛ⋅n_off⋅nₒₙ  - 2⋅α ⋅μₛ⋅nₒₙ  + α ⋅n_o
#
# __                          __________________________________________________
# 2       3   2      2       ╱  2   2      2               2           2      2
#    + 2⋅α ⋅μₛ ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off
# ──────────────────────────────────────────────────────────────────────────────
#
#   6      4      5           4      4    2       4      3    3       4      2
# ff  + 6⋅α ⋅n_off ⋅nₒₙ + 15⋅α ⋅n_off ⋅nₒₙ  + 20⋅α ⋅n_off ⋅nₒₙ  + 15⋅α ⋅n_off ⋅n
#
# _______________________________________________________________________
#      2              2    2         2                                 2     3
# + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + α ⋅μ
# ──────────────────────────────────────────────────────────────────────────────
#
#   4      4          5    4    6      3   4      2       3   3      3      3
# ₒₙ  + 6⋅α ⋅n_off⋅nₒₙ  + α ⋅nₒₙ  + 4⋅α ⋅μₛ ⋅n_off  + 12⋅α ⋅μₛ ⋅n_off  + 6⋅α ⋅μₛ
#
#                                                                   ____________
#  2    4      3         5      3         4          3         4   ╱  2   2
# ₛ ⋅nₒₙ  - 4⋅α ⋅μₛ⋅n_off  - 8⋅α ⋅μₛ⋅n_off ⋅nₒₙ + 3⋅α ⋅μₛ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                 ______________________________________________
# 3      2        3   3      2   ╱  2   2      2               2           2
#  ⋅n_off ⋅nₒₙ - α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_o
#
# ______________________________________________________________________________
#  2               2           2      2      2              2    2         2
# α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________________________________________
#   2      2              2    2         2                                 2
# ff  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   +
#
# _______________________________
#                              2       3         3    2      3         3       ╱
# ⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 2⋅α ⋅μₛ⋅n_off ⋅nₒₙ  + 6⋅α ⋅μₛ⋅n_off ⋅nₒₙ⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
#                                                              _________________
#     3   2      4       3   2      3          3   2      3   ╱  2   2      2
# 12⋅α ⋅μₛ ⋅n_off  + 20⋅α ⋅μₛ ⋅n_off ⋅nₒₙ - 3⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ
#
# ______________________________________________________________________________
#   2   2      2               2           2      2      2              2    2
#  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  +
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#             2           2      2      2              2    2         2
# ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ
#
# ___________________________________________
#        2                                 2       3         2    3      3
#  2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 2⋅α ⋅μₛ⋅n_off ⋅nₒₙ  + 3⋅α ⋅μₛ⋅n_
# ──────────────────────────────────────────────────────────────────────────────
# __________________________                                                 ___
#                         2       3   2      2    2      3   2      2       ╱  2
# ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 6⋅α ⋅μₛ ⋅n_off ⋅nₒₙ  - 3⋅α ⋅μₛ ⋅n_off ⋅nₒₙ⋅╲╱  α
#
#              _________________________________________________________________
#    2    2   ╱  2   2      2               2           2      2      2
# off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#    2      2               2           2      2      2              2    2
# ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅
#
# ________________________________________________________
#      2    2         2                                 2       3             4
# ₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 2⋅α ⋅μₛ⋅n_off⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
# ________________________________________
#     2                                 2       3   2    4      3         5
# α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 2⋅α ⋅μₛ ⋅nₒₙ  + 4⋅α ⋅μₛ⋅n_off  + 14
#
#                                               ________________________________
#      3       5    3      5        3      5   ╱  2   2      2               2
# - 2⋅α ⋅μₛ⋅nₒₙ  + α ⋅n_off ⋅nₒₙ + α ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μ
# ──────────────────────────────────────────────────────────────────────────────
#                                       ________________________________________
#   3         4          3         4   ╱  2   2      2               2
# ⋅α ⋅μₛ⋅n_off ⋅nₒₙ - 3⋅α ⋅μₛ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ +
#
# ______________________________________________________________________________
#          2      2      2              2    2         2
# ₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#  2      2      2              2    2         2
# α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μ
#
# ___________                                         __________________________
#          2       3      4    2      3      4       ╱  2   2      2
# ⋅nₒₙ + μₛ   + 5⋅α ⋅n_off ⋅nₒₙ  + 4⋅α ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ___                                                ___________________________
#  2        3         3    2      3         3       ╱  2   2      2
# ₛ   + 16⋅α ⋅μₛ⋅n_off ⋅nₒₙ  - 8⋅α ⋅μₛ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2
#
# ______________________________________________________________________________
#    2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#   2           2      2      2              2    2         2
# ⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2
#
# _________________                                           __________________
#                2        3      3    3      3      3    2   ╱  2   2      2
# 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 10⋅α ⋅n_off ⋅nₒₙ  + 6⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅
# ──────────────────────────────────────────────────────────────────────────────
# ________________                                                ______________
#               2       3         2    3      3         2    2   ╱  2   2      2
# ⋅α⋅μₛ⋅nₒₙ + μₛ   + 4⋅α ⋅μₛ⋅n_off ⋅nₒₙ  - 6⋅α ⋅μₛ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α
#
# ______________________________________________________________________________
#            2           2      2      2              2    2         2
# n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                2           2      2      2              2    2         2
# ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α
#
# _________________________                                           __________
#                        2        3      2    4      3      2    3   ╱  2   2
# n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 10⋅α ⋅n_off ⋅nₒₙ  + 4⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  +
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________
#                            2       3             4      3       5    3       4
# ⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 4⋅α ⋅μₛ⋅n_off⋅nₒₙ  - 2⋅α ⋅μₛ⋅nₒₙ  + α ⋅μₛ⋅nₒₙ
#
# ______________________________________________________________________________
#    2               2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  +
# ──────────────────────────────────────────────────────────────────────────────
#     __________________________________________________________________________
#    ╱  2   2      2               2           2      2      2              2
# ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒ
#
# _________________________________                                      _______
#                                2       3          5    3          4   ╱  2   2
#  2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 5⋅α ⋅n_off⋅nₒₙ  + α ⋅n_off⋅nₒₙ ⋅╲╱  α ⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________________                _______________
#  2         2                                 2     3      5   ╱  2   2      2
# ₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - α ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅
#
# ______________________________________________________________________________
#       2               2           2      2      2              2    2
#  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#               2           2      2      2              2    2         2
# μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅
#
# ____________________________________
# 2                                 2     3    6      2   4      2       2   3
#   + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + α ⋅nₒₙ  - 6⋅α ⋅μₛ ⋅n_off  - 12⋅α ⋅μₛ ⋅n
# ──────────────────────────────────────────────────────────────────────────────
# ____________________________                      ____________________________
#                           2       3      4       ╱  2   2      2
# μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 5⋅α ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅
#
#                            ___________________________________________________
#     3      2   3      2   ╱  2   2      2               2           2      2
# _off  + 3⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  +
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#  2           2      2      2              2    2         2
# α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅
#
# ______________________________________________________________________
#     2              2    2         2                                 2       2
#  2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 6⋅α ⋅
# ──────────────────────────────────────────────────────────────────────────────
# _______________                        _______________________________________
#              2        3      3    2   ╱  2   2      2               2
# α⋅μₛ⋅nₒₙ + μₛ   - 10⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ +
#
#                                                     __________________________
#   2      4    2   2      3          2   2      3   ╱  2   2      2
# μₛ ⋅n_off  - α ⋅μₛ ⋅n_off ⋅nₒₙ + 6⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#   2      2      2              2    2         2
#  α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ +
#
# ______________________________________________________________________________
#    2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ____                        __________________________________________________
#   2        3      2    3   ╱  2   2      2               2           2      2
# μₛ   - 10⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off
#
# _________________                                                 ____________
#                2       2   2      2    2      2   2      2       ╱  2   2
# 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 3⋅α ⋅μₛ ⋅n_off ⋅nₒₙ  + 3⋅α ⋅μₛ ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________________________________________
#      2              2    2         2                                 2       3
# + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 5⋅α
#
# ______________________________________________________________________________
#  2               2           2      2      2              2    2         2
# α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2
# ──────────────────────────────────────────────────────────────────────────────
#                _______________________________________________________________
#           4   ╱  2   2      2               2           2      2      2
# ⋅n_off⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅
#
# _______________________________
#                              2       2   2    4      2         4          2
# ⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 2⋅α ⋅μₛ ⋅nₒₙ  + 3⋅α ⋅μₛ⋅n_off ⋅nₒₙ + 3⋅α ⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
# __________________________________________________________              ______
#        2    2         2                                 2     3    5   ╱  2
# nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - α ⋅nₒₙ ⋅╲╱  α ⋅μₛ
#
#            ___________________________________________________________________
#       4   ╱  2   2      2               2           2      2      2
# ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# 2      2               2           2      2      2              2    2
#   + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μ
#
# ______________________________________________________
#    2    2         2                                 2       2         3    2
# + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 7⋅α ⋅μₛ⋅n_off ⋅nₒₙ  +
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________________
#  2                                 2       2   4      2       2   3      3
# ₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 6⋅α ⋅μₛ ⋅n_off  + 12⋅α ⋅μₛ ⋅n_off  + 6
#
#                        _______________________________________________________
#     2         3       ╱  2   2      2               2           2      2
#  4⋅α ⋅μₛ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α
# ──────────────────────────────────────────────────────────────────────────────
#                                         ______________________________________
#   2   3      2          2   3      2   ╱  2   2      2               2
# ⋅α ⋅μₛ ⋅n_off ⋅nₒₙ - 3⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ
#
# __________________________________________________________________
# 2              2    2         2                                 2       2
#  ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 3⋅α ⋅μₛ⋅n
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#    2      2      2              2    2         2
# + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ +
#
#                                                                _______________
#     2    3      2             4      2       5    2       4   ╱  2   2      2
# _off ⋅nₒₙ  - 3⋅α ⋅μₛ⋅n_off⋅nₒₙ  - 2⋅α ⋅μₛ⋅nₒₙ  + α ⋅μₛ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅
# ──────────────────────────────────────────────────────────────────────────────
# _____                                                               __________
#    2       2   2      4       2   2      3          2   2      3   ╱  2   2
#  μₛ   + 6⋅α ⋅μₛ ⋅n_off  + 10⋅α ⋅μₛ ⋅n_off ⋅nₒₙ - 6⋅α ⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  +
#
# ______________________________________________________________________________
#               2           2      2      2              2    2         2
# μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#    2               2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  +
#
# ____________________________                    ______________________________
#                           2     2      4       ╱  2   2      2               2
# μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - α ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α
# ──────────────────────────────────────────────────────────────────────────────
# _________________________________
#                                2       2   2      2    2      2   2      2
#  2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 3⋅α ⋅μₛ ⋅n_off ⋅nₒₙ  - 6⋅α ⋅μₛ ⋅n_off ⋅nₒₙ
#
# ______________________________________________________________________________
#            2      2      2              2    2         2
# ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅
# ──────────────────────────────────────────────────────────────────────────────
#     __________________________________________________________________________
#    ╱  2   2      2               2           2      2      2              2
# ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒ
#
# _____________                       __________________________________________
#            2       2      3    2   ╱  2   2      2               2           2
# μₛ⋅nₒₙ + μₛ   - 4⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________________
#  2         2                                 2     2   2    4      2         4
# ₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + α ⋅μₛ ⋅nₒₙ  - 3⋅α ⋅μₛ⋅n_off
#
# ______________________________________________________________________________
#       2      2              2    2         2                                 2
# ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ──────────────────────────────────────────────────────────────────────────────
#     __________________________________________________________________________
#    ╱  2   2      2               2           2      2      2              2
# ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒ
#
# _                       ______________________________________________________
#        2      2    3   ╱  2   2      2               2           2      2
#   - 6⋅α ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________________                         ______
#  2         2                                 2       2         3       ╱  2
# ₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 8⋅α ⋅μₛ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ
#
# ___________________________________________________________________
#  2              2    2         2                                 2       2
# α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 4⋅α ⋅n_o
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# 2      2               2           2      2      2              2    2
#   + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μ
#
#            ___________________________________________________________________
#       4   ╱  2   2      2               2           2      2      2
# ff⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________________                          _______________
#  2                                 2       2         2    2   ╱  2   2      2
# ₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 6⋅α ⋅μₛ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅
#
# ______________________________________________________              __________
#    2    2         2                                 2     2    5   ╱  2   2
# + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - α ⋅nₒₙ ⋅╲╱  α ⋅μₛ  +
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#               2           2      2      2              2    2         2
# μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅
#
# ______________________________________________________________________________
#    2               2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  +
# ──────────────────────────────────────────────────────────────────────────────
# ____________________________                 _________________________________
#                           2     2       4   ╱  2   2      2               2
# μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + α ⋅μₛ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ
#
# _________________________________
#                                2          4      2         3      3         3
#  2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 4⋅α⋅μₛ ⋅n_off  - 4⋅α⋅μₛ ⋅n_off  + 2⋅α⋅μₛ ⋅
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#         2      2      2              2    2         2
# ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅
#
#                                _______________________________________________
#      2             3      2   ╱  2   2      2               2           2
# n_off ⋅nₒₙ + 3⋅α⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_of
# ──────────────────────────────────────────────────────────────────────────────
# __________
#         2          4      2         3      3         3      2             3
# nₒₙ + μₛ   + 4⋅α⋅μₛ ⋅n_off  + 4⋅α⋅μₛ ⋅n_off  + 2⋅α⋅μₛ ⋅n_off ⋅nₒₙ - 3⋅α⋅μₛ ⋅n_
#
# __________________________________________________________________________
#  2      2              2    2         2                                 2
# f  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + 3
# ──────────────────────────────────────────────────────────────────────────────
#         ______________________________________________________________________
#    2   ╱  2   2      2               2           2      2      2
# off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α
#
#                                       ________________________________________
#      2      3             2      3   ╱  2   2      2               2
# ⋅α⋅μₛ ⋅n_off ⋅nₒₙ + 3⋅α⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ +
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________________                     ______
# 2    2         2                                 2          2      3   ╱  2
#  ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 3⋅α⋅μₛ ⋅n_off ⋅╲╱  α ⋅μₛ
#
# ______________________________________________________________________________
#  2      2      2              2    2         2
# α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# 2      2               2           2      2      2              2    2
#   + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μ
#
# ___                                                           ________________
#  2          2      2    2       2    4               3       ╱  2   2      2
# ₛ   + 2⋅α⋅μₛ ⋅n_off ⋅nₒₙ  + α⋅μₛ ⋅nₒₙ  - 2⋅α⋅μₛ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μ
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________________                         ________________
#  2                                 2          2      2       ╱  2   2      2
# ₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 3⋅α⋅μₛ ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μ
#
# ______________________________________________________________________________
#              2           2      2      2              2    2         2
# ₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#              2           2      2      2              2    2         2
# ₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μ
#
# ___________________________                         __________________________
#                          2                2    2   ╱  2   2      2
# ₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   - 3⋅α⋅μₛ⋅n_off ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________                              _____________________
#                          2      4      2     3      2   ╱  2   2      2
# ₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + μₛ ⋅n_off  - μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_o
#
# ______________________________________________________________________________
#    2           2      2      2              2    2         2
# 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off -
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#         2           2      2      2              2    2         2
# ff - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_o
#
# _________________                _____________________________________________
#                2            4   ╱  2   2      2               2           2
# 2⋅α⋅μₛ⋅nₒₙ + μₛ   + α⋅μₛ⋅nₒₙ ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_
# ──────────────────────────────────────────────────────────────────────────────
# ______________________
#                     2
# ff - 2⋅α⋅μₛ⋅nₒₙ + μₛ
#
# ____________________________________________________________________________
#    2      2              2    2         2                                 2
# off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                              _________________________________
#    4      2     3      2         3      2   ╱  2   2      2               2
#  μₛ ⋅n_off  + μₛ ⋅n_off ⋅nₒₙ + μₛ ⋅n_off ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#         2      2      2              2    2         2
# ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# __________                     _______________________________________________
#         2      2      2       ╱  2   2      2               2           2
# nₒₙ + μₛ   - μₛ ⋅n_off ⋅nₒₙ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_of
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# __________________________________________________________________________
#  2      2              2    2         2                                 2
# f  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ──────────────────────────────────────────────────────────────────────────

# %%
a = summation(profile_likelihood * f, (n_on, 0, oo))
b = summation(a, (n_off, 0, oo))
result = sqrt(b)

# %%
result.expand().simplify()
# Out:
#                     __________________________________________________________
#                    ╱           ∞       ∞
#                   ╱         _______ _______
#                  ╱          ╲       ╲
#                 ╱            ╲       ╲
#                ╱              ╲       ╲
#               ╱                ╲       ╲
#              ╱                  ╲       ╲
#             ╱                    ╲       ╲
# √2⋅        ╱         - α⋅μₛ⋅     ╱       ╱
#           ╱                     ╱       ╱                -n_off          -nₒₙ
#          ╱                     ╱       ╱    (2⋅α⋅(α + 1))      ⋅(2⋅α + 2)    ⋅
#         ╱                     ╱       ╱     ──────────────────────────────────
#        ╱                     ╱       ╱
#       ╱                     ╱       ╱
#      ╱                      ‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾
#    ╲╱                        False   False
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ⎛                                  ___________________________________________
# ⎜                                 ╱  2   2      2               2           2
# ⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#      2      2              2    2         2                                 2
# n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#  n_off
# ⎞      ⎛                                 _____________________________________
# ⎟      ⎜                                ╱  2   2      2               2
# ⎠     ⋅⎝α⋅μₛ + α⋅n_off + α⋅nₒₙ + μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#     2      2      2              2    2         2
#  + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
#                                                n_off!⋅nₒₙ!
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#                                                 ______________________________
#                                                ╱  2   2      2               2
#             -α⋅n_off - α⋅nₒₙ - n_off - nₒₙ + ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α
#        nₒₙ
# ______⎞     ──────────────────────────────────────────────────────────────────
#     2 ⎟
# + μₛ  ⎠   ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
# ______________________________________________________________________________
#            2      2      2              2    2         2
# ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2⋅(α +
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#                    ___________________________________________________________
# _____________     ╱  2   2      2               2           2      2      2
#            2    ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_
# μₛ⋅nₒₙ + μₛ   + ──────────────────────────────────────────────────────────────
#                                                                              α
# ──────────────────────────────────────────────────────────────────────────────
# 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                                                                       ∞
#                                                                    _______ ___
#                                                                    ╲       ╲
# ______________________________________________________________      ╲       ╲
#            2    2         2                                 2        ╲       ╲
# off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ          ╲
# ──────────────────────────────────────────────────────────────         ╲
#                                                                         ╲
# ────────────────────────────────────────────────────────────── + α⋅     ╱
#                                                                        ╱
#                                                                       ╱
# ──────────────────────────────────────────────────────────────       ╱       ╱
#                                                                     ╱       ╱
#                                                                    ╱       ╱
#                                                                    ‾‾‾‾‾‾‾ ‾‾‾
#                                                                     False   Fa
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
# ∞
# ____
#
#
#
# ╲
#  ╲
#   ╲
#   ╱                                          ⎛
#  ╱                      -n_off          -nₒₙ ⎜
# ╱    n_off⋅(2⋅α⋅(α + 1))      ⋅(2⋅α + 2)    ⋅⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲
#      ─────────────────────────────────────────────────────────────────────────
#
#
# ‾‾‾‾
# lse
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#   ____________________________________________________________________________
#  ╱  2   2      2               2           2      2      2              2    2
# ╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#                                               n_off
# _____________________________________________⎞      ⎛
#          2                                 2 ⎟      ⎜
#  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ  ⎠     ⋅⎝α⋅μₛ + α⋅n_off + α⋅nₒₙ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#         ______________________________________________________________________
#        ╱  2   2      2               2           2      2      2
# μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#                                                          -α⋅n_off - α⋅nₒₙ - n_
#                                                     nₒₙ
# ___________________________________________________⎞     ─────────────────────
# 2    2         2                                 2 ⎟
#  ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ  ⎠   ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#            n_off!⋅nₒₙ!
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#                _______________________________________________________________
#               ╱  2   2      2               2           2      2      2
# off - nₒₙ + ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#                                                                 ______________
# __________________________________________________________     ╱  2   2      2
#        2    2         2                                 2    ╲╱  α ⋅μₛ  + 2⋅α
# nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + ─────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#                                       2⋅(α + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
# ______________________________________________________________________________
#                2           2      2      2              2    2         2
# ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α
# ──────────────────────────────────────────────────────────────────────────────
#                                             α
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                                      ∞       ∞
#                                   _______ _______
#                                   ╲       ╲
# _____________________________      ╲       ╲
#                            2        ╲       ╲
# ⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ          ╲       ╲
# ─────────────────────────────         ╲       ╲
#                                        ╲       ╲
# ───────────────────────────── + α⋅     ╱       ╱
#                                       ╱       ╱                    -n_off
#                                      ╱       ╱    nₒₙ⋅(2⋅α⋅(α + 1))      ⋅(2⋅α
# ─────────────────────────────       ╱       ╱     ────────────────────────────
#                                    ╱       ╱
#                                   ╱       ╱
#                                   ‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾
#                                    False   False
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#           ⎛                                  _________________________________
#      -nₒₙ ⎜                                 ╱  2   2      2               2
#  + 2)    ⋅⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#         2      2      2              2    2         2
# ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#            n_off
# __________⎞      ⎛                                 ___________________________
#         2 ⎟      ⎜                                ╱  2   2      2
# nₒₙ + μₛ  ⎠     ⋅⎝α⋅μₛ + α⋅n_off + α⋅nₒₙ + μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#   2           2      2      2              2    2         2
# ⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2
# ──────────────────────────────────────────────────────────────────────────────
#                                                        n_off!⋅nₒₙ!
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#                                                           ____________________
#                                                          ╱  2   2      2
#                       -α⋅n_off - α⋅nₒₙ - n_off - nₒₙ + ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_
#                  nₒₙ
# ________________⎞     ────────────────────────────────────────────────────────
#               2 ⎟
# ⋅α⋅μₛ⋅nₒₙ + μₛ  ⎠   ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                        _______
#                                 2⋅√α⋅╲╱ α + 1
#
# ______________________________________________________________________________
#
#
#
#
# ______________________________________________________________________________
#          2           2      2      2              2    2         2
# off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#                              _________________________________________________
# _______________________     ╱  2   2      2               2           2      2
#                      2    ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off
# off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + ────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#    2⋅(α + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
# ________________________________________________________________________
#       2              2    2         2                                 2
#  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ
# ────────────────────────────────────────────────────────────────────────
#          α
# ──────────────────────────────────────────────────────────────────────── - μₛ⋅
#
#
# ────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#    ∞       ∞
# _______ _______
# ╲       ╲
#  ╲       ╲
#   ╲       ╲
#    ╲       ╲
#     ╲       ╲
#      ╲       ╲
#      ╱       ╱                                    ⎛
#     ╱       ╱                -n_off          -nₒₙ ⎜
#    ╱       ╱    (2⋅α⋅(α + 1))      ⋅(2⋅α + 2)    ⋅⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μ
#   ╱       ╱     ──────────────────────────────────────────────────────────────
#  ╱       ╱
# ╱       ╱
# ‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾
#  False   False
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#        _______________________________________________________________________
#       ╱  2   2      2               2           2      2      2              2
# ₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#                                                    n_off
# __________________________________________________⎞      ⎛
#     2         2                                 2 ⎟      ⎜
# ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ  ⎠     ⋅⎝α⋅μₛ + α⋅n_off + α⋅n
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#              _________________________________________________________________
#             ╱  2   2      2               2           2      2      2
# ₒₙ + μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
# ...
#                                       False   False
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
#          ⎛                                  __________________________________
#     -nₒₙ ⎜                                 ╱  2   2      2               2
# + 2)    ⋅⎝-α⋅μₛ + α⋅n_off + α⋅nₒₙ - μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#        2      2      2              2    2         2
# nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅n
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#           n_off
# _________⎞      ⎛                                 ____________________________
#        2 ⎟      ⎜                                ╱  2   2      2
# ₒₙ + μₛ  ⎠     ⋅⎝α⋅μₛ + α⋅n_off + α⋅nₒₙ + μₛ - ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#  2           2      2      2              2    2         2
# α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#
#                 nₒₙ
# _______________⎞       _______________________________________________________
#              2 ⎟      ╱  2   2      2               2           2      2
# α⋅μₛ⋅nₒₙ + μₛ  ⎠   ⋅╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α
# ──────────────────────────────────────────────────────────────────────────────
#                                          n_off!⋅nₒₙ!
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#
#
#                                                                     -α⋅n_off -
#
# __________________________________________________________________  ──────────
# 2              2    2         2                                 2
#  ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ  ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#
#                           ____________________________________________________
#                          ╱  2   2      2               2           2      2
#  α⋅nₒₙ - n_off - nₒₙ + ╲╱  α ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  +
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
#                                                                            ___
# _____________________________________________________________________     ╱  2
#    2              2    2         2                                 2    ╲╱  α
# 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ   + ──────
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2⋅(α + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#
#
# ______________________________________________________________________________
#    2      2               2           2      2      2              2    2
# ⋅μₛ  + 2⋅α ⋅μₛ⋅n_off - 2⋅α ⋅μₛ⋅nₒₙ + α ⋅n_off  + 2⋅α ⋅n_off⋅nₒₙ + α ⋅nₒₙ  + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                        α
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _________________________________________
#
#
#
# ________________________________________      ⎛  α           2         1    ⎞
#     2                                 2    μₛ⋅⎜───── - 2 + ───── + ─────────⎟
# α⋅μₛ  + 2⋅α⋅μₛ⋅n_off - 2⋅α⋅μₛ⋅nₒₙ + μₛ        ⎝α + 1       α + 1   α⋅(α + 1)⎠
# ────────────────────────────────────────   ──────────────────────────────────
#                                                            4
# ──────────────────────────────────────── ⋅ℯ
#
#
# ────────────────────────────────────────
#
#
#
#
# ─────────────────────────────────────────────────────────────────────────────
