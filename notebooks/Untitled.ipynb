# %%
from utils import plot_spectra, Log10Parabola
import astropy.units as u
import matplotlib.pyplot as plt

from gammapy.spectrum import CrabSpectrum, SpectrumObservationList, SpectrumExtraction
from gammapy.data.event_list import EventList
from gammapy.background import ReflectedRegionsBackgroundEstimator
# %matplotlib inline

# %%
l = EventList.read('../data/magic/run_05029747_DL3.fits')

# %%
# Out:
# <Quantity [0.08397394, 0.10596932, 0.19733498, ..., 0.17672835, 0.12345374,
#            0.13630114] TeV>

# %%
spec_obs = SpectrumObservationList.read('./spectra/custom/magic/')

print(obs.lo_threshold.to('TeV'), obs.hi_threshold.to('TeV'), obs.on_vector.counts_in_safe_range.shape, obs.off_vector.counts_in_safe_range.shape)

for obs in spec_obs:
    obs.aeff.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-95ea8fe6c447> in <module>
#       1 spec_obs = SpectrumObservationList.read('./spectra/custom/magic/')
#       2 obs = spec_obs
# ----> 3 print(obs.lo_threshold.to('TeV'), obs.hi_threshold.to('TeV'), obs.on_vector.counts_in_safe_range.shape, obs.off_vector.counts_in_safe_range.shape)
#       4
#       5 for obs in spec_obs:
#
# AttributeError: 'SpectrumObservationList' object has no attribute 'lo_threshold'

# %%
obs.on_vector.energy.bins.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5c9640c06463> in <module>
# ----> 1 obs.on_vector.energy.bins.value
#
# AttributeError: 'SpectrumObservationList' object has no attribute 'on_vector'

# %%
c = obs.on_vector.counts_in_safe_range.value
# bins = obs.energy.bins.to("TeV").value

x = obs.e_reco.lower_bounds.to_value('TeV')
plt.step(x, c, where='post')
plt.xscale('log')
plt.xlabel('Energy')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# #### Todo
#
# energy limits per instrument. create datsets with few bins. then run it again.

# %%
plt.figure(figsize=(14, 10))

mle_model = Log10Parabola(
    amplitude=3.73 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.49 * u.Unit(''),
    beta=0.36 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='orange', label='veritas')
mle_model = Log10Parabola(
    amplitude=3.70 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.45 * u.Unit(''),
    beta=0.31 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='orange', label='veritas paper', ls='--')
mle_model = Log10Parabola(
    amplitude=3.82 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.51 * u.Unit(''),
    beta=0.4 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='orange', label='veritas high', ls=':')





mle_model = Log10Parabola(
    amplitude=4.04 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.6 * u.Unit(''),
    beta=0.44 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='red', label='magic')
mle_model = Log10Parabola(
    amplitude=4.20 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.58 * u.Unit(''),
    beta=0.43 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, ls='--', color='red', label='magic paper')
mle_model = Log10Parabola(
    amplitude=4.10 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.63 * u.Unit(''),
    beta=0.48 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, ls=':', color='red', label='magic high')




mle_model = Log10Parabola(
    amplitude=3.45 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.52 * u.Unit(''),
    beta=0.47 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='blue', label='fact')
mle_model = Log10Parabola(
    amplitude=3.47 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.56 * u.Unit(''),
    beta=0.4 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='blue', label='fact paper', ls='--')
mle_model = Log10Parabola(
    amplitude=3.50 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.7 * u.Unit(''),
    beta=0.24 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='blue', label='fact high', ls=':')




mle_model = Log10Parabola(
    amplitude=4.02 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.36 * u.Unit(''),
    beta=0.43 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='darkgreen', label='hess')
mle_model = Log10Parabola(
    amplitude=4.38 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.35 * u.Unit(''),
    beta=0.22 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='darkgreen', label='hess paper', ls='--')
mle_model = Log10Parabola(
    amplitude=4.13 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.49 * u.Unit(''),
    beta=0.46 * u.Unit(''),
)
mle_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='darkgreen', label='hess high', ls=':')


# 4.1289344 2.3414993 0.46681368 


joint_model = Log10Parabola(
    amplitude=3.78 * 1e-11 * u.Unit('cm-2 s-1 TeV-1'),
    reference=1 * u.Unit('TeV'),
    alpha=2.49 * u.Unit(''),
    beta=0.22 * u.Unit(''),
)
joint_model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='black', label='joint')

crab = CrabSpectrum(reference='meyer')
crab.model.plot(energy_range=[0.1, 30]* u.TeV, energy_power=2, color='gray', label='mayer')
plt.legend()
